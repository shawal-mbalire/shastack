# %% [markdown]
# # Exploratory Data Analysis
# This notebook contains sample EDA for the Shastack ML module.

# %%
import torch
from src.model import SimpleNet

model = SimpleNet()
print(f"Model parameters: {sum(p.numel() for p in model.parameters())}")
